# %%
import numpy as np

import matplotlib.pyplot as plt

# %% [markdown]
# __Задание.__ Разложить в ряд Фурье функцию
# $$ f(x) = (3x + 1)^2 $$
# на интервале $x \in (-1, 1)$. Построить графики рассматриваемой функции и
# суммы ряда Фурье. Найти значения ряда Фурье в граничных точках рассматриваемого отрезка и в точках разрыва. С использованием программных
# средств построить суммы ряда Фурье для 1, 2, 5 и 10 слагаемых, обосновать сходимость ряда.

# %% [markdown]
# _Теорема Дирихле._ Если
# 1. функция $f(x)$ непрерывна или имеет конечное число точек разрыва 1-го рода на на отрезке $[a, b]$,
# 2. функция $f(x)$ монотонна или имеет конечное число точек экстремума на отрезке $[a, b]$,
#
# то ряд Фурье функции $f(x)$ сходится
#
# 1. к периодическому продолжению функции $f(x)$ внутри интервала $(a, b)$ во всех точках, где функция $f(x)$ непрерывна;
# 2. к полусумме левого и правого пределов функции $f(x)$, если периодическое продолжение имеет разрывы 1-го рода в точке $x_0$:
# $$ \dfrac{1}{2} \left( f(x_0^{-}) + f(x_0^{+}) \right); $$

# %% [markdown]
# Данная функция непрерывна на отрезке $[-1, 1]$ и имеет одну точку экстремума:
# $$ \dfrac{df}{dx} = 2 (3x + 1) \cdot 3 = 6(3x + 1) = 0 $$
# Отсюда $x = -\dfrac{1}{3} \in [-1, 1]$ — точка минимума функции $f(x)$. В этом легко убедиться, построив график.

# %%
L = 1

def f(x: float):
    return (3 * x + 1)**2

# %%
x = np.linspace(-L, L, 100)  # генерируем значения x на заданном интервале

fig = plt.figure(figsize=(15, 8))

plt.plot(x, f(x), linewidth=3, label='f(x)')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# _Ряд Фурье._ Если функция $f(x)$ удовлетворяет условиям Дирихле, то ее можно разложить в ряд Фурье на заданном интервале $[-L, L]$:
# $$ f(x) \sim \dfrac{a_0}{2} + \sum\limits_{n = 1}^\infty a_n \cos \dfrac{n \pi x}{L} + b_n \sin \dfrac{n \pi x}{L}, $$
# где коэффициенты $a_0$, $a_n$, $b_n$, $n = 1, 2, \dots$ вычисляются по формулам:
# $$ a_0 = \dfrac{1}{L} \int\limits_{-L}^L f(x) dx, $$
# $$ a_n = \dfrac{1}{L} \int\limits_{-L}^L f(x) \cos\dfrac{n \pi x}{L} dx, \quad n = 1, 2, \dots $$
# $$ b_n = \dfrac{1}{L} \int\limits_{-L}^L f(x) \sin\dfrac{n \pi x}{L} dx, \quad n = 1, 2, \dots $$

# %% [markdown]
# Используя данные формулы, получаем
# $$ a_0 = 8, \quad a_n = \dfrac{36}{(\pi n)^2} (-1)^n, \quad b_n = -\dfrac{12}{\pi n} (-1)^n, \quad n = 1, 2, \dots $$

# %% [markdown]
# Таким образом, ряд Фурье имеет вид
# $$ f(x) \sim 4 + \sum\limits_{n = 1}^\infty \left[ \dfrac{36}{(\pi n)^2} (-1)^n \cos \pi n x - \dfrac{12}{\pi n} (-1)^n \sin \pi n x \right] $$
#
# Частную сумму ряда Фурье будем записывать в виде
# $$ S_N(x) =  4 + \sum\limits_{n = 1}^N \left[ \dfrac{36}{(\pi n)^2} (-1)^n \cos \pi n x - \dfrac{12}{\pi n} (-1)^n \sin \pi n x \right] $$

# %% [markdown]
# _Граничные точки._ Согласно условиям Дирихле, значение ряда Фурье на границах отрезка $[-1, 1]$ равняется полусумме предельных значений функции $f(x)$:
# $$ S_N(-1) = \dfrac{1}{2} (f(-1^{-}) + f(-1^{+})) = \dfrac{16 + 4}{2} = 10,$$
# $$ S_N(1) = \dfrac{1}{2} (f(1^{-}) + f(1^{+})) = \dfrac{4 + 16}{2} = 10.$$

# %% [markdown]
# _Точки разрыва._ Так как функция $f(x)$ непрерывна на $-1 < x < 1$, то определять значения ряда Фурье в точках разрыва не требуется.

# %%
x = np.linspace(-L, L, 100)  # генерируем значения x на заданном интервале
x_left = np.linspace(-3*L, -L, 100)
x_right = np.linspace(L, 3*L, 100)

# точки разрыва
x0, y0 = -1, 10
x1, y1 = 1, 10

fig = plt.figure(figsize=(20, 8))

plt.plot(x, f(x), linewidth=3, color='blue', linestyle='-', label='f(x)')
plt.plot(x_left, f(x), linewidth=3, color='blue', linestyle='--', label='Периодическое продолжение f(x)')
plt.plot(x_right, f(x), linewidth=3, color='blue', linestyle='--')

plt.plot(x0, y0, 'ro', label='Значения ряда Фурье в точках разрыва / граничных точках')
plt.plot(x1, y1, 'ro')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# _Обоснование сходимости ряда с помощью программных средств._

# %%
# коэффициенты ряда Фурье
def a(n: int):
    if n > 0:     # коэффициенты a_n
        return 36 / (np.pi * n) ** 2 * (-1) ** n
    elif n == 0:  # коэффициент a_0
        return 8


def b(n: int):
    if n > 0:     # коэффициенты b_n
        return -12 / (np.pi * n) * (-1) ** n

# %%
# частная сумма ряда Фурье  
def S(x: float, N: int):
    s = 0
    # внутри интервала
    if -L < x < L:
        s = a(0) / 2
        for n in range(1, N + 1):
            s += a(n) * np.cos(np.pi * n * x) + b(n) * np.sin(np.pi * n * x)
    # в граничных точках
    elif x == -L or x == L:
        s = 1 / 2 * (f(-L) + f(L))
    
    return s

# %%
S2 = np.vectorize(S)

fig = plt.figure(figsize=(15, 8))

plt.plot(x, f(x), linewidth=3, label='f(x)')
plt.plot(x, S2(x, 1), linewidth=3, label='S(x, 1)')
plt.plot(x, S2(x, 2), linewidth=3, label='S(x, 2)')
plt.plot(x, S2(x, 5), linewidth=3, label='S(x, 5)')
plt.plot(x, S2(x, 10), linewidth=3, label='S(x, 10)')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# __Задание.__ Разложить в ряд Фурье функцию
# $$ f(x) =
#   \begin{cases}
#     1       & \quad 0 \leq x < 1 \\
#     4x  & \quad 1 < x \leq 2
#   \end{cases}
# $$
# на интервале $x \in (0, 2)$. Построить графики рассматриваемой функции и
# суммы ряда Фурье. Найти значения ряда Фурье в граничных точках рассматриваемого отрезка и в точках разрыва. С использованием программных
# средств построить суммы ряда Фурье для 1, 2, 5 и 10 слагаемых, обосновать сходимость ряда.

# %%
L = 2
def f(x: float):
    if 0 <= x <= 1:
        return 1
    elif 1 < x <= 2:
        return 4 * x
    
    return None

# %% [markdown]
# Данная функция имеет разрыв в точке $x = 1$ и монотонна на отрезке $[0, 2]$ за исключением точки разрыва:
# $$ \dfrac{df}{dx} = \begin{cases} 0, & 0 \leq x < 1 \\
#                                     4, & 1 < x \leq 2\end{cases}$$

# %%
x_0_1 = np.linspace(0, 1, 100)  # генерируем значения x на заданном интервале
x_1_2 = np.linspace(1.001, 2, 100)

x_1, y_min, y_max = 1, 1, 4 # точка разрыва

fig = plt.figure(figsize=(15, 8))

plt.plot(x_0_1, list(map(f, x_0_1)), linewidth=3, color='blue', label='f(x)')
plt.plot(x_1_2, list(map(f, x_1_2)), linewidth=3, color='blue')

plt.vlines(x=x_1, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--', label='Точка разрыва')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# _Ряд Фурье._ Разложим функцию $f(x)$ в ряд Фурье по косинусам. Для этого построим четное продолжение функции следующим образом:
# $$ g(x) = \begin{cases} -4x, & -2 \leq x < -1, \\
#                           1, & -1 \leq x \leq 1, \\
#                          4x, & 1 < x \leq 2. \end{cases} $$

# %%
def g(x: float):
    if -2 <= x < -1:
        return -4 * x
    elif -1 <= x <= 1:
        return 1
    elif 1 < x <= 2:
        return 4 * x
    
    return None

# %%
# генерируем значения x на заданном интервале
x_m2_m1 = np.linspace(-2, -1.001, 100)
x_m1_1 = np.linspace(-1, 1, 100)
x_1_2 = np.linspace(1.001, 2, 100)

x_1, y_min, y_max = 1, 1, 4 # точка разрыва
x_m1 = -1

fig = plt.figure(figsize=(15, 8))

plt.plot(x_m2_m1, list(map(g, x_m2_m1)), linewidth=3, color='blue', label='g(x)')
plt.plot(x_1_2, list(map(g, x_1_2)), linewidth=3, color='blue')
plt.plot(x_m1_1, list(map(g, x_m1_1)), linewidth=3, color='blue')

plt.vlines(x=x_1, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--', label='Точки разрыва')
plt.vlines(x=x_m1, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# Тогда ряд Фурье на $\left[ -2, 2 \right]$ для функции $g(x)$ имеет вид
# $$ g(x) \sim \sum\limits_{n = 0}^\infty a_n \cos\left( \dfrac{n \pi x}{L} \right) = \sum\limits_{n = 0}^\infty a_n \cos\left( \dfrac{n \pi x}{2} \right), $$
# где коэффициенты $a_n$ считаются по формуле:
# $$ a_n = \dfrac{2}{L} \int\limits_0^L g(x) \cos\left( \dfrac{n \pi x}{L} \right) dx = \int\limits_0^2 g(x) \cos\left( \dfrac{n \pi x}{2} \right) dx. $$
#
# Тогда, так как $g(x) = f(x)$ на $\left[0, 2 \right]$ мы можем записать ряд Фурье для $f(x)$ как
# $$ f(x) \sim  \sum\limits_{n = 0}^\infty a_n \cos\left( \dfrac{n \pi x}{2} \right), $$
# где коэффициенты $a_n$ считаются по формуле:
# $$ a_n = \int\limits_0^2 f(x) \cos\left( \dfrac{n \pi x}{2} \right) dx. $$
#
# Коэффициенты для ряда Фурье имеют вид
# $$ a_0 = 7, \quad a_n = \dfrac{4}{(\pi n)^2} \left( 1 - (-1)^n \right), \quad b_n = \dfrac{3 (-1)^n - 7}{\pi n}, \quad n = 1, 2, \dots $$
#
# Тогда,
# $$ f(x) \sim 7 + \sum\limits_{n = 1}^\infty \left[ \dfrac{4}{(\pi n)^2} \left( 1 - (-1)^n \right) \cos(\pi n x) + \dfrac{3 (-1)^n - 7}{\pi n} \sin(\pi n x) \right] $$
#
# Частную сумму будем записывать как
# $$ S_N(x) = 7 + \sum\limits_{n = 1}^N \left[ \dfrac{4}{(\pi n)^2} \left( 1 - (-1)^n \right) \cos(\pi n x) + \dfrac{3 (-1)^n - 7}{\pi n} \sin(\pi n x) \right] $$

# %% [markdown]
# _Граничные точки._ Согласно условиям Дирихле, значение ряда Фурье на границах отрезка $[-2, 2]$ равняется полусумме предельных значений функции $g(x)$:
# $$ S(-2) = \dfrac{f(-2^{-}) + f(-2^{+})}{2} = \dfrac{8 + 8}{2} = 8, $$
# $$ S(2) = \dfrac{f(2^{-}) + f(2^{+})}{2} = \dfrac{8 + 8}{2} = 8. $$
#
# При этом для исходной функции $f(x)$, определенной на $[0, 2]$ правая граница остается такой же $S(2) = 8$, а на левой границе
# $$ S(0) = \dfrac{f(0^{-}) + f(0^{+})}{2} = \dfrac{1 + 1}{2} = 1. $$

# %% [markdown]
# _Точки разрыва._ Согласно условиям Дирихле, значение ряда Фурье в точке разрыва $x_0 = \pm 1$ равняется полусумме левого и правого пределов функции $g(x)$ в этих точках:
# $$ S(-1) = \dfrac{g(-1^{-}) + g(-1^{+})}{2} = \dfrac{4 + 1}{2} = 2.5, $$
# $$ S(1) = \dfrac{g(-1^{-}) + g(-1^{+})}{2} = \dfrac{1 + 4}{2} = 2.5. $$
#
# Для функции $f(x)$ имеем только одну точку разрыва в $x = 1$, поэтому нам необходимо определить только значение ряда Фурье в этой точке: $S(1) = 2.5$

# %%
# генерируем значения x на заданном интервале
x_m2_m1 = np.linspace(-2, -1.001, 100)
x_m1_1 = np.linspace(-1, 1, 100)
x_1_2 = np.linspace(1.001, 2, 100)

x_m6_m5 = np.linspace(-6, -5.001, 100)
x_m5_m3 = np.linspace(-5, -3, 100)
x_m3_m2 = np.linspace(-2.999, -2.001, 100)

x_2_3 = np.linspace(2.001, 2.999, 100)
x_3_5 = np.linspace(3, 5, 100)
x_5_6 = np.linspace(5.001, 6, 100)

fig = plt.figure(figsize=(25, 8))

plt.plot(x_m2_m1, list(map(g, x_m2_m1)), linewidth=3, color='blue', label='g(x)')
plt.plot(x_m1_1, list(map(g, x_m1_1)), linewidth=3, color='blue')
plt.plot(x_1_2, list(map(g, x_1_2)), linewidth=3, color='blue')
plt.plot(x_m6_m5, list(map(g, x_m2_m1)), linewidth=3, color='blue')
plt.plot(x_m5_m3, list(map(g, x_m1_1)), linewidth=3, color='blue')
plt.plot(x_m3_m2, list(map(g, x_1_2)), linewidth=3, color='blue')
plt.plot(x_2_3, list(map(g, x_m2_m1)), linewidth=3, color='blue')
plt.plot(x_3_5, list(map(g, x_m1_1)), linewidth=3, color='blue')
plt.plot(x_5_6, list(map(g, x_1_2)), linewidth=3, color='blue')


x_1, y_min, y_max = 1, 1, 4 # точка разрыва
x_m1 = -1
x_m3 = -3
x_m5 = -5
x_3 = 3
x_5 = 5

plt.vlines(x=x_1, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--', label='Точки разрыва')
plt.vlines(x=x_m1, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')
plt.vlines(x=x_m3, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')
plt.vlines(x=x_m5, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')
plt.vlines(x=x_3, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')
plt.vlines(x=x_5, ymin=y_min, ymax=y_max, linewidth=2, color='k', linestyle='--')

y_m1, y_1 = 2.5, 2.5
x_m2, y_m2 = -2, 8
x_2, y_2 = 2, 8

plt.plot(x_m1, y_m1, 'ro', label='Значения ряда Фурье в точках разрыва / граничных точках')
plt.plot(x_1, y_1, 'ro')
plt.plot(x_m2, y_m2, 'ro')
plt.plot(x_2, y_m2, 'ro')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# _Обоснование сходимости ряда с помощью программных средств._

# %%
def a(n: int):
    if n > 0:
        return -6 / (np.pi * n) * np.sin(n * np.pi / 2) + 16 / (np.pi ** 2 * n ** 2) * ((-1) ** n - np.cos(n * np.pi / 2))
    elif n == 0:
        return 7
    
def S(x: float, N: int):
    if 0 < x < 1 or 1 < x < 2:
        s = a(0) / 2
        for n in range(1, N + 1):
            s += a(n) * np.cos(np.pi * n * x / 2)
    elif x == 1:
        s = 1 / 2 * (f(0.99) + f(1.01))
    elif x == 0:
        s = 1 / 2 * (g(-0.001) + g(0.001))
    elif x == 2:
        s = 1 / 2 * (g(1.999) + g(-1.999))
    
    return s

# %%
x = np.arange(0, 2.01, 0.01)
f2 = np.vectorize(f)
S2 = np.vectorize(S)

fig = plt.figure(figsize=(15, 8))

plt.plot(x, list(map(f, x)), linewidth=3, label='f(x)')
plt.plot(x, S2(x, 1), linewidth=3, label='S(x, 1)')
plt.plot(x, S2(x, 2), linewidth=3, label='S(x, 2)')
plt.plot(x, S2(x, 5), linewidth=3, label='S(x, 5)')
plt.plot(x, S2(x, 10), linewidth=3, label='S(x, 10)')

plt.xlabel('x')
plt.ylabel('y')
plt.grid()
plt.legend()
plt.show()
